# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
import warnings as wrn
from utils.helper import *
wrn.filterwarnings('ignore', category = DeprecationWarning) 
wrn.filterwarnings('ignore', category = FutureWarning) 
wrn.filterwarnings('ignore', category = UserWarning)
wrn.filterwarnings('ignore', category = RuntimeWarning)
# %matplotlib inline

# %%
DATA_PATH = "data/"
USERNAME = "Silvia Valleria"

# %%
data = pd.read_csv(DATA_PATH + "Database Silvia Valleria Content List - db.csv")
data.tail()
# Out:
#     id                        title  views              date  \
# 37  38    The Rise of Silvilization   3276  18-December-2022
# 38  39   membaca nama nama penduduk   4431  21-December-2022
# 39  40  Unique games with Silvia #2   3449  23-December-2022
# 40  41                     halo dek   3481  27-December-2022
# 41  42          What I want in 2023   3729    1-January-2023
#
#                                                  url game_name  \
# 37  https://www.youtube.com/watch?v=EBWfSlSosOY&t=3s       NaN
# 38       https://www.youtube.com/watch?v=RbhHJr50kbA       NaN
# 39       https://www.youtube.com/watch?v=HQ5lKnPoi1w       NaN
# 40       https://www.youtube.com/watch?v=lGzI3kmFQTM       NaN
# 41       https://www.youtube.com/watch?v=HuHxpupYVbI       NaN
#
#                        content_name      topic  duration start_stream  \
# 37                  Membership Open  Free Talk  01:04:46        19:00
# 38               Membership Reading  Free Talk  02:37:44        20:00
# 39  Unique games with Silvia (Usil)       Game  01:37:10        12:50
# 40                              NaN  Free Talk  01:11:50        10:00
# 41                              NaN  Free Talk  01:47:40        01:00
#
#    end_stream          note Last Update
# 37      20:04           NaN         NaN
# 38      22:37           NaN         NaN
# 39      14:27  random games         NaN
# 40      11:11           NaN         NaN
# 41      02:47           NaN         NaN

# %%
data.shape
# Out:
# (42, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            42 non-null     int64
#  1   title         42 non-null     object
#  2   views         42 non-null     int64
#  3   date          42 non-null     object
#  4   url           42 non-null     object
#  5   game_name     21 non-null     object
#  6   content_name  15 non-null     object
#  7   topic         42 non-null     object
#  8   duration      42 non-null     object
#  9   start_stream  42 non-null     object
#  10  end_stream    42 non-null     object
#  11  note          2 non-null      object
#  12  Last Update   2 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 4.4+ KB

# %%
COLS = ['url', 'note', "Last Update"]

# %%
data.drop(COLS, axis=1, inplace=True)

# %% [markdown]
# ### Impute missing values with `UNKNOWN` value

# %%
impute_missing_values(data=data, columns = ["game_name", "content_name"])
# Out:
#     id                                              title  views  \
# 0    1             Ask me anything since I'm feeling nice   3039
# 1    2            belajar menembak untuk memajukan negara   2548
# 2    3                               tentara harus berani   1847
# 3    4                                   gimana hari ini?   4578
# 4    5                                     janji ga takut   1659
# 5    6                                 pagi, latihan yuk?   3379
# 6    7                                ga lucu = deportasi   3793
# 7    8                                    jadi ubi gepeng   2420
# 8    9                    menguji kekebalan melawan buaya   4509
# 9   10                                    gampang ini mah   1404
# 10  11                                    udah lama, sini   2824
# 11  12                      kapakku tidak mungkin meleset   1422
# 12  13                            loncat loncat doang kan   1676
# 13  14                                         kapan lagi   3260
# 14  15                         apakah iya game ini susah?   1663
# 15  16                                 jadi sebenernya...   3154
# 16  17                                  deg degan ga yaaa   1566
# 17  18                                                dor   1350
# 18  19                                day off, let's talk   1985
# 19  20                aku akan bermain dengan senang hati   1438
# 20  21                     apakah wallpaper kalian bagus?   3843
# 21  22                           menilai wallpaper part 2   2467
# 22  23                        orang chill main game chill   1481
# 23  24                                        about today   3161
# 24  25                   jaga jarak dah kalo kata gua mah   1385
# 25  26                  menjelajah melihat keindahan alam   1416
# 26  27                              perang melawan zombie   2322
# 27  28                                         first time   5054
# 28  29                   kekuasaan mutlak ada di tanganku   2547
# 29  30                           Unique games with Silvia   4764
# 30  31                                   pvz di pagi hari   2891
# 31  32                 membicarakan strategi untuk menang   5083
# 32  33            kita harus salut dengan dedikasi mereka   2752
# 33  34  di pagi hari yang damai ini kita akan menyusun...   5010
# 34  35                 aku akan menjadi komandan terkeren   7874
# 35  36                          kali ini sabar dan santai   2925
# 36  37                       cerita apa yang akan terjadi   3907
# 37  38                          The Rise of Silvilization   3276
# 38  39                         membaca nama nama penduduk   4431
# 39  40                        Unique games with Silvia #2   3449
# 40  41                                           halo dek   3481
# 41  42                                What I want in 2023   3729
#
#                  date                   game_name  \
# 0   30-September-2022                     UNKNOWN
# 1      1-October-2022                    Valorant
# 2      2-October-2022            Dead by Daylight
# 3      3-October-2022                     UNKNOWN
# 4     07-October-2022                      Ao Oni
# 5     08-October-2022                     UNKNOWN
# 6     08-October-2022                     UNKNOWN
# 7     12-October-2022                      Ao Oni
# 8     15-October-2022                     UNKNOWN
# 9     20-October-2022           The Witch's House
# 10    23-October-2022                     UNKNOWN
# 11    24-October-2022            Dead by Daylight
# 12    26-October-2022                   Jump King
# 13    30-October-2022                     UNKNOWN
# 14    4-November-2022                     Cuphead
# 15    6-November-2022                     UNKNOWN
# 16    7-November-2022           Little Nightmares
# 17   12-November-2022                    Valorant
# 18   13-November-2022                     UNKNOWN
# 19   14-November-2022           Little Nightmares
# 20   18-November-2022                     UNKNOWN
# 21   19-November-2022                     UNKNOWN
# 22   20-November-2022    When The Past Was Around
# 23   21-November-2022                     UNKNOWN
# 24   24-November-2022           Little Nightmares
# 25   25-November-2022  Alba: A Wildlife Adventure
# 26   27-November-2022          Plants vs. Zombies
# 27   01-December-2022                     UNKNOWN
# 28   04-December-2022                  The Sims 4
# 29   05-December-2022                     UNKNOWN
# 30   07-December-2022          Plants vs. Zombies
# 31   08-December-2022                     UNKNOWN
# 32   09-December-2022                     UNKNOWN
# 33   10-December-2022       Cats Organized Neatly
# 34   10-December-2022                       Nikke
# 35   12-December-2022                   Jump King
# 36   14-December-2022             Citampi Stories
# 37   18-December-2022                     UNKNOWN
# 38   21-December-2022                     UNKNOWN
# 39   23-December-2022                     UNKNOWN
# 40   27-December-2022                     UNKNOWN
# 41     1-January-2023                     UNKNOWN
#
#                        content_name      topic  duration start_stream  \
# 0                           UNKNOWN  Free Talk  02:04:13        20:00
# 1                           UNKNOWN       Game  01:40:28        21:00
# 2                           UNKNOWN       Game  01:36:08        20:00
# 3                           UNKNOWN  Free Talk  01:41:08        19:30
# 4                           UNKNOWN       Game  02:09:46        20:00
# 5                          Guerilla  Free Talk  02:17:21        09:00
# 6        Waktu Silvia Menilai (WSM)  Free Talk  02:06:46        21:00
# 7                           UNKNOWN       Game  02:01:30        20:00
# 8        Waktu Silvia Menilai (WSM)  Free Talk  02:07:58        20:00
# 9                           UNKNOWN       Game  01:31:25        20:00
# 10                          UNKNOWN  Free Talk  02:02:28        10:00
# 11                          UNKNOWN       Game  02:14:50        20:00
# 12                          UNKNOWN       Game  01:41:21        16:00
# 13             Singing you to sleep    Karaoke  01:32:16        21:30
# 14                          UNKNOWN       Game  02:19:58        15:30
# 15                          UNKNOWN  Free Talk  02:07:47        10:00
# 16                          UNKNOWN       Game  02:05:16        19:30
# 17                          UNKNOWN       Game  02:06:48        15:30
# 18                          UNKNOWN  Free Talk  02:12:41        10:00
# 19                          UNKNOWN       Game  02:07:58        20:30
# 20       Waktu Silvia Menilai (WSM)  Free Talk  01:39:42        20:00
# 21       Waktu Silvia Menilai (WSM)  Free Talk  01:19:54        15:00
# 22                          UNKNOWN       Game  02:04:52        13:00
# 23                          UNKNOWN  Free Talk  03:33:32        20:00
# 24                          UNKNOWN       Game  02:08:34        21:00
# 25                          UNKNOWN       Game  02:04:26        13:30
# 26                          UNKNOWN       Game  02:03:42        20:30
# 27                       Mediashare  Free Talk  04:35:54        20:00
# 28                          UNKNOWN       Game  02:06:08        13:00
# 29  Unique games with Silvia (Usil)       Game  02:06:46        20:00
# 30                         Guerilla       Game  01:38:00        10:20
# 31                       Mediashare  Free Talk  03:06:29        20:00
# 32       Waktu Silvia Menilai (WSM)  Free Talk  01:10:32        15:15
# 33                         Guerilla       Game  02:28:24        10:10
# 34                          UNKNOWN       Game  03:40:54        22:00
# 35                          UNKNOWN       Game  01:23:52        13:20
# 36                          UNKNOWN       Game  01:32:56        15:30
# 37                  Membership Open  Free Talk  01:04:46        19:00
# 38               Membership Reading  Free Talk  02:37:44        20:00
# 39  Unique games with Silvia (Usil)       Game  01:37:10        12:50
# 40                          UNKNOWN  Free Talk  01:11:50        10:00
# 41                          UNKNOWN  Free Talk  01:47:40        01:00
#
#    end_stream
# 0       22:04
# 1       22:40
# 2       21:36
# 3       21:11
# 4       22:09
# 5       11:17
# 6       23:06
# 7       22:01
# 8       22:07
# 9       21:31
# 10      12:02
# 11      22:14
# 12      17:41
# 13      23:02
# 14      17:49
# 15      12:07
# 16      21:35
# 17      17:36
# 18      12:12
# 19      22:37
# 20      21:39
# 21      16:19
# 22      15:04
# 23      23:33
# 24      23:08
# 25      15:34
# 26      22:33
# 27      00:35
# 28      15:06
# 29      22:06
# 30      11:58
# 31      23:06
# 32      16:25
# 33      12:38
# 34      01:40
# 35      14:43
# 36      17:02
# 37      20:04
# 38      22:37
# 39      14:27
# 40      11:11
# 41      02:47

# %%
data.isna().sum()
# Out:
# id              0
# title           0
# views           0
# date            0
# game_name       0
# content_name    0
# topic           0
# duration        0
# start_stream    0
# end_stream      0
# dtype: int64

# %% [markdown]
# ### Convert Data into datetime

# %% [markdown]
# #### Get Days

# %%
convert_date_to_days(data=data)
# Out:
#     id                                              title  views       date  \
# 0    1             Ask me anything since I'm feeling nice   3039 2022-09-30
# 1    2            belajar menembak untuk memajukan negara   2548 2022-10-01
# 2    3                               tentara harus berani   1847 2022-10-02
# 3    4                                   gimana hari ini?   4578 2022-10-03
# 4    5                                     janji ga takut   1659 2022-10-07
# 5    6                                 pagi, latihan yuk?   3379 2022-10-08
# 6    7                                ga lucu = deportasi   3793 2022-10-08
# 7    8                                    jadi ubi gepeng   2420 2022-10-12
# 8    9                    menguji kekebalan melawan buaya   4509 2022-10-15
# 9   10                                    gampang ini mah   1404 2022-10-20
# 10  11                                    udah lama, sini   2824 2022-10-23
# 11  12                      kapakku tidak mungkin meleset   1422 2022-10-24
# 12  13                            loncat loncat doang kan   1676 2022-10-26
# 13  14                                         kapan lagi   3260 2022-10-30
# 14  15                         apakah iya game ini susah?   1663 2022-11-04
# 15  16                                 jadi sebenernya...   3154 2022-11-06
# 16  17                                  deg degan ga yaaa   1566 2022-11-07
# 17  18                                                dor   1350 2022-11-12
# 18  19                                day off, let's talk   1985 2022-11-13
# 19  20                aku akan bermain dengan senang hati   1438 2022-11-14
# 20  21                     apakah wallpaper kalian bagus?   3843 2022-11-18
# 21  22                           menilai wallpaper part 2   2467 2022-11-19
# 22  23                        orang chill main game chill   1481 2022-11-20
# 23  24                                        about today   3161 2022-11-21
# 24  25                   jaga jarak dah kalo kata gua mah   1385 2022-11-24
# 25  26                  menjelajah melihat keindahan alam   1416 2022-11-25
# 26  27                              perang melawan zombie   2322 2022-11-27
# 27  28                                         first time   5054 2022-12-01
# 28  29                   kekuasaan mutlak ada di tanganku   2547 2022-12-04
# 29  30                           Unique games with Silvia   4764 2022-12-05
# 30  31                                   pvz di pagi hari   2891 2022-12-07
# 31  32                 membicarakan strategi untuk menang   5083 2022-12-08
# 32  33            kita harus salut dengan dedikasi mereka   2752 2022-12-09
# 33  34  di pagi hari yang damai ini kita akan menyusun...   5010 2022-12-10
# 34  35                 aku akan menjadi komandan terkeren   7874 2022-12-10
# 35  36                          kali ini sabar dan santai   2925 2022-12-12
# 36  37                       cerita apa yang akan terjadi   3907 2022-12-14
# 37  38                          The Rise of Silvilization   3276 2022-12-18
# 38  39                         membaca nama nama penduduk   4431 2022-12-21
# 39  40                        Unique games with Silvia #2   3449 2022-12-23
# 40  41                                           halo dek   3481 2022-12-27
# 41  42                                What I want in 2023   3729 2023-01-01
#
#                      game_name                     content_name      topic  \
# 0                      UNKNOWN                          UNKNOWN  Free Talk
# 1                     Valorant                          UNKNOWN       Game
# 2             Dead by Daylight                          UNKNOWN       Game
# 3                      UNKNOWN                          UNKNOWN  Free Talk
# 4                       Ao Oni                          UNKNOWN       Game
# 5                      UNKNOWN                         Guerilla  Free Talk
# 6                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 7                       Ao Oni                          UNKNOWN       Game
# 8                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 9            The Witch's House                          UNKNOWN       Game
# 10                     UNKNOWN                          UNKNOWN  Free Talk
# 11            Dead by Daylight                          UNKNOWN       Game
# 12                   Jump King                          UNKNOWN       Game
# 13                     UNKNOWN             Singing you to sleep    Karaoke
# 14                     Cuphead                          UNKNOWN       Game
# 15                     UNKNOWN                          UNKNOWN  Free Talk
# 16           Little Nightmares                          UNKNOWN       Game
# 17                    Valorant                          UNKNOWN       Game
# 18                     UNKNOWN                          UNKNOWN  Free Talk
# 19           Little Nightmares                          UNKNOWN       Game
# 20                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 21                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 22    When The Past Was Around                          UNKNOWN       Game
# 23                     UNKNOWN                          UNKNOWN  Free Talk
# 24           Little Nightmares                          UNKNOWN       Game
# 25  Alba: A Wildlife Adventure                          UNKNOWN       Game
# 26          Plants vs. Zombies                          UNKNOWN       Game
# 27                     UNKNOWN                       Mediashare  Free Talk
# 28                  The Sims 4                          UNKNOWN       Game
# 29                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 30          Plants vs. Zombies                         Guerilla       Game
# 31                     UNKNOWN                       Mediashare  Free Talk
# 32                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 33       Cats Organized Neatly                         Guerilla       Game
# 34                       Nikke                          UNKNOWN       Game
# 35                   Jump King                          UNKNOWN       Game
# 36             Citampi Stories                          UNKNOWN       Game
# 37                     UNKNOWN                  Membership Open  Free Talk
# 38                     UNKNOWN               Membership Reading  Free Talk
# 39                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 40                     UNKNOWN                          UNKNOWN  Free Talk
# 41                     UNKNOWN                          UNKNOWN  Free Talk
#
#     duration start_stream end_stream    days
# 0   02:04:13        20:00      22:04  Jum'at
# 1   01:40:28        21:00      22:40   Sabtu
# 2   01:36:08        20:00      21:36  Minggu
# 3   01:41:08        19:30      21:11   Senin
# 4   02:09:46        20:00      22:09  Jum'at
# 5   02:17:21        09:00      11:17   Sabtu
# 6   02:06:46        21:00      23:06   Sabtu
# 7   02:01:30        20:00      22:01    Rabu
# 8   02:07:58        20:00      22:07   Sabtu
# 9   01:31:25        20:00      21:31   Kamis
# 10  02:02:28        10:00      12:02  Minggu
# 11  02:14:50        20:00      22:14   Senin
# 12  01:41:21        16:00      17:41    Rabu
# 13  01:32:16        21:30      23:02  Minggu
# 14  02:19:58        15:30      17:49  Jum'at
# 15  02:07:47        10:00      12:07  Minggu
# 16  02:05:16        19:30      21:35   Senin
# 17  02:06:48        15:30      17:36   Sabtu
# 18  02:12:41        10:00      12:12  Minggu
# 19  02:07:58        20:30      22:37   Senin
# 20  01:39:42        20:00      21:39  Jum'at
# 21  01:19:54        15:00      16:19   Sabtu
# 22  02:04:52        13:00      15:04  Minggu
# 23  03:33:32        20:00      23:33   Senin
# 24  02:08:34        21:00      23:08   Kamis
# 25  02:04:26        13:30      15:34  Jum'at
# 26  02:03:42        20:30      22:33  Minggu
# 27  04:35:54        20:00      00:35   Kamis
# 28  02:06:08        13:00      15:06  Minggu
# 29  02:06:46        20:00      22:06   Senin
# 30  01:38:00        10:20      11:58    Rabu
# 31  03:06:29        20:00      23:06   Kamis
# 32  01:10:32        15:15      16:25  Jum'at
# 33  02:28:24        10:10      12:38   Sabtu
# 34  03:40:54        22:00      01:40   Sabtu
# 35  01:23:52        13:20      14:43   Senin
# 36  01:32:56        15:30      17:02    Rabu
# 37  01:04:46        19:00      20:04  Minggu
# 38  02:37:44        20:00      22:37    Rabu
# 39  01:37:10        12:50      14:27  Jum'at
# 40  01:11:50        10:00      11:11  Selasa
# 41  01:47:40        01:00      02:47  Minggu

# %% [markdown]
# #### Get Hours

# %%
get_hours(data=data)
# Out:
#     id                                              title  views       date  \
# 0    1             Ask me anything since I'm feeling nice   3039 2022-09-30
# 1    2            belajar menembak untuk memajukan negara   2548 2022-10-01
# 2    3                               tentara harus berani   1847 2022-10-02
# 3    4                                   gimana hari ini?   4578 2022-10-03
# 4    5                                     janji ga takut   1659 2022-10-07
# 5    6                                 pagi, latihan yuk?   3379 2022-10-08
# 6    7                                ga lucu = deportasi   3793 2022-10-08
# 7    8                                    jadi ubi gepeng   2420 2022-10-12
# 8    9                    menguji kekebalan melawan buaya   4509 2022-10-15
# 9   10                                    gampang ini mah   1404 2022-10-20
# 10  11                                    udah lama, sini   2824 2022-10-23
# 11  12                      kapakku tidak mungkin meleset   1422 2022-10-24
# 12  13                            loncat loncat doang kan   1676 2022-10-26
# 13  14                                         kapan lagi   3260 2022-10-30
# 14  15                         apakah iya game ini susah?   1663 2022-11-04
# 15  16                                 jadi sebenernya...   3154 2022-11-06
# 16  17                                  deg degan ga yaaa   1566 2022-11-07
# 17  18                                                dor   1350 2022-11-12
# 18  19                                day off, let's talk   1985 2022-11-13
# 19  20                aku akan bermain dengan senang hati   1438 2022-11-14
# 20  21                     apakah wallpaper kalian bagus?   3843 2022-11-18
# 21  22                           menilai wallpaper part 2   2467 2022-11-19
# 22  23                        orang chill main game chill   1481 2022-11-20
# 23  24                                        about today   3161 2022-11-21
# 24  25                   jaga jarak dah kalo kata gua mah   1385 2022-11-24
# 25  26                  menjelajah melihat keindahan alam   1416 2022-11-25
# 26  27                              perang melawan zombie   2322 2022-11-27
# 27  28                                         first time   5054 2022-12-01
# 28  29                   kekuasaan mutlak ada di tanganku   2547 2022-12-04
# 29  30                           Unique games with Silvia   4764 2022-12-05
# 30  31                                   pvz di pagi hari   2891 2022-12-07
# 31  32                 membicarakan strategi untuk menang   5083 2022-12-08
# 32  33            kita harus salut dengan dedikasi mereka   2752 2022-12-09
# 33  34  di pagi hari yang damai ini kita akan menyusun...   5010 2022-12-10
# 34  35                 aku akan menjadi komandan terkeren   7874 2022-12-10
# 35  36                          kali ini sabar dan santai   2925 2022-12-12
# 36  37                       cerita apa yang akan terjadi   3907 2022-12-14
# 37  38                          The Rise of Silvilization   3276 2022-12-18
# 38  39                         membaca nama nama penduduk   4431 2022-12-21
# 39  40                        Unique games with Silvia #2   3449 2022-12-23
# 40  41                                           halo dek   3481 2022-12-27
# 41  42                                What I want in 2023   3729 2023-01-01
#
#                      game_name                     content_name      topic  \
# 0                      UNKNOWN                          UNKNOWN  Free Talk
# 1                     Valorant                          UNKNOWN       Game
# 2             Dead by Daylight                          UNKNOWN       Game
# 3                      UNKNOWN                          UNKNOWN  Free Talk
# 4                       Ao Oni                          UNKNOWN       Game
# 5                      UNKNOWN                         Guerilla  Free Talk
# 6                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 7                       Ao Oni                          UNKNOWN       Game
# 8                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 9            The Witch's House                          UNKNOWN       Game
# 10                     UNKNOWN                          UNKNOWN  Free Talk
# 11            Dead by Daylight                          UNKNOWN       Game
# 12                   Jump King                          UNKNOWN       Game
# 13                     UNKNOWN             Singing you to sleep    Karaoke
# 14                     Cuphead                          UNKNOWN       Game
# 15                     UNKNOWN                          UNKNOWN  Free Talk
# 16           Little Nightmares                          UNKNOWN       Game
# 17                    Valorant                          UNKNOWN       Game
# 18                     UNKNOWN                          UNKNOWN  Free Talk
# 19           Little Nightmares                          UNKNOWN       Game
# 20                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 21                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 22    When The Past Was Around                          UNKNOWN       Game
# 23                     UNKNOWN                          UNKNOWN  Free Talk
# 24           Little Nightmares                          UNKNOWN       Game
# 25  Alba: A Wildlife Adventure                          UNKNOWN       Game
# 26          Plants vs. Zombies                          UNKNOWN       Game
# 27                     UNKNOWN                       Mediashare  Free Talk
# 28                  The Sims 4                          UNKNOWN       Game
# 29                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 30          Plants vs. Zombies                         Guerilla       Game
# 31                     UNKNOWN                       Mediashare  Free Talk
# 32                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 33       Cats Organized Neatly                         Guerilla       Game
# 34                       Nikke                          UNKNOWN       Game
# 35                   Jump King                          UNKNOWN       Game
# 36             Citampi Stories                          UNKNOWN       Game
# 37                     UNKNOWN                  Membership Open  Free Talk
# 38                     UNKNOWN               Membership Reading  Free Talk
# 39                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 40                     UNKNOWN                          UNKNOWN  Free Talk
# 41                     UNKNOWN                          UNKNOWN  Free Talk
#
#     duration start_stream end_stream    days  hours
# 0   02:04:13     20:00:00      22:04  Jum'at     20
# 1   01:40:28     21:00:00      22:40   Sabtu     21
# 2   01:36:08     20:00:00      21:36  Minggu     20
# 3   01:41:08     19:30:00      21:11   Senin     19
# 4   02:09:46     20:00:00      22:09  Jum'at     20
# 5   02:17:21     09:00:00      11:17   Sabtu      9
# 6   02:06:46     21:00:00      23:06   Sabtu     21
# 7   02:01:30     20:00:00      22:01    Rabu     20
# 8   02:07:58     20:00:00      22:07   Sabtu     20
# 9   01:31:25     20:00:00      21:31   Kamis     20
# 10  02:02:28     10:00:00      12:02  Minggu     10
# 11  02:14:50     20:00:00      22:14   Senin     20
# 12  01:41:21     16:00:00      17:41    Rabu     16
# 13  01:32:16     21:30:00      23:02  Minggu     21
# 14  02:19:58     15:30:00      17:49  Jum'at     15
# 15  02:07:47     10:00:00      12:07  Minggu     10
# 16  02:05:16     19:30:00      21:35   Senin     19
# 17  02:06:48     15:30:00      17:36   Sabtu     15
# 18  02:12:41     10:00:00      12:12  Minggu     10
# 19  02:07:58     20:30:00      22:37   Senin     20
# 20  01:39:42     20:00:00      21:39  Jum'at     20
# 21  01:19:54     15:00:00      16:19   Sabtu     15
# 22  02:04:52     13:00:00      15:04  Minggu     13
# 23  03:33:32     20:00:00      23:33   Senin     20
# 24  02:08:34     21:00:00      23:08   Kamis     21
# 25  02:04:26     13:30:00      15:34  Jum'at     13
# 26  02:03:42     20:30:00      22:33  Minggu     20
# 27  04:35:54     20:00:00      00:35   Kamis     20
# 28  02:06:08     13:00:00      15:06  Minggu     13
# 29  02:06:46     20:00:00      22:06   Senin     20
# 30  01:38:00     10:20:00      11:58    Rabu     10
# 31  03:06:29     20:00:00      23:06   Kamis     20
# 32  01:10:32     15:15:00      16:25  Jum'at     15
# 33  02:28:24     10:10:00      12:38   Sabtu     10
# 34  03:40:54     22:00:00      01:40   Sabtu     22
# 35  01:23:52     13:20:00      14:43   Senin     13
# 36  01:32:56     15:30:00      17:02    Rabu     15
# 37  01:04:46     19:00:00      20:04  Minggu     19
# 38  02:37:44     20:00:00      22:37    Rabu     20
# 39  01:37:10     12:50:00      14:27  Jum'at     12
# 40  01:11:50     10:00:00      11:11  Selasa     10
# 41  01:47:40     01:00:00      02:47  Minggu      1

# %% [markdown]
# ### Get count days for Livestream

# %%
data["days"].value_counts()
# Out:
# Minggu    10
# Sabtu      8
# Jum'at     7
# Senin      7
# Rabu       5
# Kamis      4
# Selasa     1
# Name: days, dtype: int64

# %%
print(f"Selama 3 bulan ini, Silvia sudah melakukan stream sebanyak {len(data.index)} kali")
# Out:
# Selama 3 bulan ini, Silvia sudah melakukan stream sebanyak 42 kali

# %% [markdown]
# ### Plot Livestream Days in 3 months

# %%
plot_count_days(data=data, username=USERNAME)

# %% [markdown]
# ### Get Average Views based on Days

# %%
get_avg_days = round(data.groupby(["days"])['views'].mean().reindex(["Senin","Selasa","Rabu","Kamis","Jum'at","Sabtu","Minggu"]), 2)

# %%
get_avg_days
# Out:
# days
# Senin     2836.29
# Selasa    3481.00
# Rabu      3065.00
# Kamis     3231.50
# Jum'at    2545.86
# Sabtu     3866.25
# Minggu    2642.50
# Name: views, dtype: float64

# %%
plot_avg_days_views(data=data,
                    var_name=get_avg_days,
                    username=USERNAME)

# %% [markdown]
# ### Get count hours livestream

# %%
data["hours"].value_counts()
# Out:
# 20    15
# 10     6
# 15     5
# 21     4
# 13     4
# 19     3
# 9      1
# 16     1
# 22     1
# 12     1
# 1      1
# Name: hours, dtype: int64

# %%
plot_count_hours(data=data, username=USERNAME)

# %% [markdown]
# ### Trend Views in 3 months

# %%
min(data["date"]), max(data["date"])
# Out:
# (Timestamp('2022-09-30 00:00:00'), Timestamp('2023-01-01 00:00:00'))

# %%
plot_trend_views(data=data, username=USERNAME, max_limit=8000)

# %%
min_views = min(data["views"])
min_views
# Out:
# 1350

# %%
data[data["views"] == min_views]
# Out:
#     id title  views       date game_name content_name topic  duration  \
# 17  18   dor   1350 2022-11-12  Valorant      UNKNOWN  Game  02:06:48
#
#    start_stream end_stream   days  hours
# 17     15:30:00      17:36  Sabtu     15

# %%
max_views = max(data["views"])
max_views
# Out:
# 7874

# %%
data[data["views"] == max_views]
# Out:
#     id                               title  views       date game_name  \
# 34  35  aku akan menjadi komandan terkeren   7874 2022-12-10     Nikke
#
#    content_name topic  duration start_stream end_stream   days  hours
# 34      UNKNOWN  Game  03:40:54     22:00:00      01:40  Sabtu     22

# %% [markdown]
# ### Views distribution

# %%
plot_distribution(data=data, col="views")

# %% [markdown]
# ### Get average views

# %%
mean = np.average(data['views'])
mean
# Out:
# 3018.1428571428573

# %% [markdown]
# ### Get median views

# %%
median = np.median(data['views'])
median
# Out:
# 2908.0

# %% [markdown]
# ### Get average views in each hours

# %%
data.head()
# Out:
#    id                                    title  views       date  \
# 0   1   Ask me anything since I'm feeling nice   3039 2022-09-30
# 1   2  belajar menembak untuk memajukan negara   2548 2022-10-01
# 2   3                     tentara harus berani   1847 2022-10-02
# 3   4                         gimana hari ini?   4578 2022-10-03
# 4   5                           janji ga takut   1659 2022-10-07
#
#           game_name content_name      topic  duration start_stream end_stream  \
# 0           UNKNOWN      UNKNOWN  Free Talk  02:04:13     20:00:00      22:04
# 1          Valorant      UNKNOWN       Game  01:40:28     21:00:00      22:40
# 2  Dead by Daylight      UNKNOWN       Game  01:36:08     20:00:00      21:36
# 3           UNKNOWN      UNKNOWN  Free Talk  01:41:08     19:30:00      21:11
# 4            Ao Oni      UNKNOWN       Game  02:09:46     20:00:00      22:09
#
#      days  hours
# 0  Jum'at     20
# 1   Sabtu     21
# 2  Minggu     20
# 3   Senin     19
# 4  Jum'at     20

# %%
avg_views_hours = round(data.groupby(['hours'])["views"].mean(), 2)

# %%
avg_views_hours
# Out:
# hours
# 1     3729.00
# 9     3379.00
# 10    3224.17
# 12    3449.00
# 13    2092.25
# 15    2427.80
# 16    1676.00
# 19    3140.00
# 20    3093.07
# 21    2746.50
# 22    7874.00
# Name: views, dtype: float64

# %% [markdown]
# ### Plot Average Views in each Hours

# %%
plot_avg_views_hours(data=data, var_name=avg_views_hours, username=USERNAME)

# %%
data[data["hours"] == 22]
# Out:
#     id                               title  views       date game_name  \
# 34  35  aku akan menjadi komandan terkeren   7874 2022-12-10     Nikke
#
#    content_name topic  duration start_stream end_stream   days  hours
# 34      UNKNOWN  Game  03:40:54     22:00:00      01:40  Sabtu     22

# %% [markdown]
# ### Convert Timestamp duration to Minutes

# %%
convert_timestamp_to_minutes(data=data)
# Out:
#     id                                              title  views       date  \
# 0    1             Ask me anything since I'm feeling nice   3039 2022-09-30
# 1    2            belajar menembak untuk memajukan negara   2548 2022-10-01
# 2    3                               tentara harus berani   1847 2022-10-02
# 3    4                                   gimana hari ini?   4578 2022-10-03
# 4    5                                     janji ga takut   1659 2022-10-07
# 5    6                                 pagi, latihan yuk?   3379 2022-10-08
# 6    7                                ga lucu = deportasi   3793 2022-10-08
# 7    8                                    jadi ubi gepeng   2420 2022-10-12
# 8    9                    menguji kekebalan melawan buaya   4509 2022-10-15
# 9   10                                    gampang ini mah   1404 2022-10-20
# 10  11                                    udah lama, sini   2824 2022-10-23
# 11  12                      kapakku tidak mungkin meleset   1422 2022-10-24
# 12  13                            loncat loncat doang kan   1676 2022-10-26
# 13  14                                         kapan lagi   3260 2022-10-30
# 14  15                         apakah iya game ini susah?   1663 2022-11-04
# 15  16                                 jadi sebenernya...   3154 2022-11-06
# 16  17                                  deg degan ga yaaa   1566 2022-11-07
# 17  18                                                dor   1350 2022-11-12
# 18  19                                day off, let's talk   1985 2022-11-13
# 19  20                aku akan bermain dengan senang hati   1438 2022-11-14
# 20  21                     apakah wallpaper kalian bagus?   3843 2022-11-18
# 21  22                           menilai wallpaper part 2   2467 2022-11-19
# 22  23                        orang chill main game chill   1481 2022-11-20
# 23  24                                        about today   3161 2022-11-21
# 24  25                   jaga jarak dah kalo kata gua mah   1385 2022-11-24
# 25  26                  menjelajah melihat keindahan alam   1416 2022-11-25
# 26  27                              perang melawan zombie   2322 2022-11-27
# 27  28                                         first time   5054 2022-12-01
# 28  29                   kekuasaan mutlak ada di tanganku   2547 2022-12-04
# 29  30                           Unique games with Silvia   4764 2022-12-05
# 30  31                                   pvz di pagi hari   2891 2022-12-07
# 31  32                 membicarakan strategi untuk menang   5083 2022-12-08
# 32  33            kita harus salut dengan dedikasi mereka   2752 2022-12-09
# 33  34  di pagi hari yang damai ini kita akan menyusun...   5010 2022-12-10
# 34  35                 aku akan menjadi komandan terkeren   7874 2022-12-10
# 35  36                          kali ini sabar dan santai   2925 2022-12-12
# 36  37                       cerita apa yang akan terjadi   3907 2022-12-14
# 37  38                          The Rise of Silvilization   3276 2022-12-18
# 38  39                         membaca nama nama penduduk   4431 2022-12-21
# 39  40                        Unique games with Silvia #2   3449 2022-12-23
# 40  41                                           halo dek   3481 2022-12-27
# 41  42                                What I want in 2023   3729 2023-01-01
#
#                      game_name                     content_name      topic  \
# 0                      UNKNOWN                          UNKNOWN  Free Talk
# 1                     Valorant                          UNKNOWN       Game
# 2             Dead by Daylight                          UNKNOWN       Game
# 3                      UNKNOWN                          UNKNOWN  Free Talk
# 4                       Ao Oni                          UNKNOWN       Game
# 5                      UNKNOWN                         Guerilla  Free Talk
# 6                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 7                       Ao Oni                          UNKNOWN       Game
# 8                      UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 9            The Witch's House                          UNKNOWN       Game
# 10                     UNKNOWN                          UNKNOWN  Free Talk
# 11            Dead by Daylight                          UNKNOWN       Game
# 12                   Jump King                          UNKNOWN       Game
# 13                     UNKNOWN             Singing you to sleep    Karaoke
# 14                     Cuphead                          UNKNOWN       Game
# 15                     UNKNOWN                          UNKNOWN  Free Talk
# 16           Little Nightmares                          UNKNOWN       Game
# 17                    Valorant                          UNKNOWN       Game
# 18                     UNKNOWN                          UNKNOWN  Free Talk
# 19           Little Nightmares                          UNKNOWN       Game
# 20                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 21                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 22    When The Past Was Around                          UNKNOWN       Game
# 23                     UNKNOWN                          UNKNOWN  Free Talk
# 24           Little Nightmares                          UNKNOWN       Game
# 25  Alba: A Wildlife Adventure                          UNKNOWN       Game
# 26          Plants vs. Zombies                          UNKNOWN       Game
# 27                     UNKNOWN                       Mediashare  Free Talk
# 28                  The Sims 4                          UNKNOWN       Game
# 29                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 30          Plants vs. Zombies                         Guerilla       Game
# 31                     UNKNOWN                       Mediashare  Free Talk
# 32                     UNKNOWN       Waktu Silvia Menilai (WSM)  Free Talk
# 33       Cats Organized Neatly                         Guerilla       Game
# 34                       Nikke                          UNKNOWN       Game
# 35                   Jump King                          UNKNOWN       Game
# 36             Citampi Stories                          UNKNOWN       Game
# 37                     UNKNOWN                  Membership Open  Free Talk
# 38                     UNKNOWN               Membership Reading  Free Talk
# 39                     UNKNOWN  Unique games with Silvia (Usil)       Game
# 40                     UNKNOWN                          UNKNOWN  Free Talk
# 41                     UNKNOWN                          UNKNOWN  Free Talk
#
#     duration start_stream end_stream    days  hours  convert_duration_minutes
# 0   02:04:13     20:00:00      22:04  Jum'at     20                    124.22
# 1   01:40:28     21:00:00      22:40   Sabtu     21                    100.47
# 2   01:36:08     20:00:00      21:36  Minggu     20                     96.13
# 3   01:41:08     19:30:00      21:11   Senin     19                    101.13
# 4   02:09:46     20:00:00      22:09  Jum'at     20                    129.77
# 5   02:17:21     09:00:00      11:17   Sabtu      9                    137.35
# 6   02:06:46     21:00:00      23:06   Sabtu     21                    126.77
# 7   02:01:30     20:00:00      22:01    Rabu     20                    121.50
# 8   02:07:58     20:00:00      22:07   Sabtu     20                    127.97
# 9   01:31:25     20:00:00      21:31   Kamis     20                     91.42
# 10  02:02:28     10:00:00      12:02  Minggu     10                    122.47
# 11  02:14:50     20:00:00      22:14   Senin     20                    134.83
# 12  01:41:21     16:00:00      17:41    Rabu     16                    101.35
# 13  01:32:16     21:30:00      23:02  Minggu     21                     92.27
# 14  02:19:58     15:30:00      17:49  Jum'at     15                    139.97
# 15  02:07:47     10:00:00      12:07  Minggu     10                    127.78
# 16  02:05:16     19:30:00      21:35   Senin     19                    125.27
# 17  02:06:48     15:30:00      17:36   Sabtu     15                    126.80
# 18  02:12:41     10:00:00      12:12  Minggu     10                    132.68
# 19  02:07:58     20:30:00      22:37   Senin     20                    127.97
# 20  01:39:42     20:00:00      21:39  Jum'at     20                     99.70
# 21  01:19:54     15:00:00      16:19   Sabtu     15                     79.90
# 22  02:04:52     13:00:00      15:04  Minggu     13                    124.87
# 23  03:33:32     20:00:00      23:33   Senin     20                    213.53
# 24  02:08:34     21:00:00      23:08   Kamis     21                    128.57
# 25  02:04:26     13:30:00      15:34  Jum'at     13                    124.43
# 26  02:03:42     20:30:00      22:33  Minggu     20                    123.70
# 27  04:35:54     20:00:00      00:35   Kamis     20                    275.90
# 28  02:06:08     13:00:00      15:06  Minggu     13                    126.13
# 29  02:06:46     20:00:00      22:06   Senin     20                    126.77
# 30  01:38:00     10:20:00      11:58    Rabu     10                     98.00
# 31  03:06:29     20:00:00      23:06   Kamis     20                    186.48
# 32  01:10:32     15:15:00      16:25  Jum'at     15                     70.53
# 33  02:28:24     10:10:00      12:38   Sabtu     10                    148.40
# 34  03:40:54     22:00:00      01:40   Sabtu     22                    220.90
# 35  01:23:52     13:20:00      14:43   Senin     13                     83.87
# 36  01:32:56     15:30:00      17:02    Rabu     15                     92.93
# 37  01:04:46     19:00:00      20:04  Minggu     19                     64.77
# 38  02:37:44     20:00:00      22:37    Rabu     20                    157.73
# 39  01:37:10     12:50:00      14:27  Jum'at     12                     97.17
# 40  01:11:50     10:00:00      11:11  Selasa     10                     71.83
# 41  01:47:40     01:00:00      02:47  Minggu      1                    107.67

# %% [markdown]
# ### Average per minutes

# %%
mean_duration = np.average(data['convert_duration_minutes'])
mean_duration
# Out:
# 124.09285714285713

# %%
data[data["convert_duration_minutes"] == max(data["convert_duration_minutes"])]
# Out:
#     id       title  views       date game_name content_name      topic  \
# 27  28  first time   5054 2022-12-01   UNKNOWN   Mediashare  Free Talk
#
#     duration start_stream end_stream   days  hours  convert_duration_minutes
# 27  04:35:54     20:00:00      00:35  Kamis     20                     275.9

# %% [markdown]
# ### Distribution Plot Stream Duration

# %%
plot_distribution(data=data, col="convert_duration_minutes")

# %% [markdown]
# ### Get average Stream Duration by Days

# %%
avg_stream_duration_days = round(data.groupby('days')['convert_duration_minutes'].mean().reindex(["Senin","Selasa","Rabu","Kamis","Jum'at","Sabtu","Minggu"]), 2)

# %%
avg_stream_duration_days
# Out:
# days
# Senin     130.48
# Selasa     71.83
# Rabu      114.30
# Kamis     170.59
# Jum'at    112.26
# Sabtu     133.57
# Minggu    111.85
# Name: convert_duration_minutes, dtype: float64

# %%
plot_avg_duration_stream_days(data=data, var_name=avg_stream_duration_days, username=USERNAME)

# %%
data[data["days"] == "Kamis"]
# Out:
#     id                               title  views       date  \
# 9   10                     gampang ini mah   1404 2022-10-20
# 24  25    jaga jarak dah kalo kata gua mah   1385 2022-11-24
# 27  28                          first time   5054 2022-12-01
# 31  32  membicarakan strategi untuk menang   5083 2022-12-08
#
#             game_name content_name      topic  duration start_stream  \
# 9   The Witch's House      UNKNOWN       Game  01:31:25     20:00:00
# 24  Little Nightmares      UNKNOWN       Game  02:08:34     21:00:00
# 27            UNKNOWN   Mediashare  Free Talk  04:35:54     20:00:00
# 31            UNKNOWN   Mediashare  Free Talk  03:06:29     20:00:00
#
#    end_stream   days  hours  convert_duration_minutes
# 9       21:31  Kamis     20                     91.42
# 24      23:08  Kamis     21                    128.57
# 27      00:35  Kamis     20                    275.90
# 31      23:06  Kamis     20                    186.48

# %%
data[data["days"] == "Sabtu"]
# Out:
#     id                                              title  views       date  \
# 1    2            belajar menembak untuk memajukan negara   2548 2022-10-01
# 5    6                                 pagi, latihan yuk?   3379 2022-10-08
# 6    7                                ga lucu = deportasi   3793 2022-10-08
# 8    9                    menguji kekebalan melawan buaya   4509 2022-10-15
# 17  18                                                dor   1350 2022-11-12
# 21  22                           menilai wallpaper part 2   2467 2022-11-19
# 33  34  di pagi hari yang damai ini kita akan menyusun...   5010 2022-12-10
# 34  35                 aku akan menjadi komandan terkeren   7874 2022-12-10
#
#                 game_name                content_name      topic  duration  \
# 1                Valorant                     UNKNOWN       Game  01:40:28
# 5                 UNKNOWN                    Guerilla  Free Talk  02:17:21
# 6                 UNKNOWN  Waktu Silvia Menilai (WSM)  Free Talk  02:06:46
# 8                 UNKNOWN  Waktu Silvia Menilai (WSM)  Free Talk  02:07:58
# 17               Valorant                     UNKNOWN       Game  02:06:48
# 21                UNKNOWN  Waktu Silvia Menilai (WSM)  Free Talk  01:19:54
# 33  Cats Organized Neatly                    Guerilla       Game  02:28:24
# 34                  Nikke                     UNKNOWN       Game  03:40:54
#
#    start_stream end_stream   days  hours  convert_duration_minutes
# 1      21:00:00      22:40  Sabtu     21                    100.47
# 5      09:00:00      11:17  Sabtu      9                    137.35
# 6      21:00:00      23:06  Sabtu     21                    126.77
# 8      20:00:00      22:07  Sabtu     20                    127.97
# 17     15:30:00      17:36  Sabtu     15                    126.80
# 21     15:00:00      16:19  Sabtu     15                     79.90
# 33     10:10:00      12:38  Sabtu     10                    148.40
# 34     22:00:00      01:40  Sabtu     22                    220.90

# %%
data[data["convert_duration_minutes"] == max(data["convert_duration_minutes"])]
# Out:
#     id       title  views       date game_name content_name      topic  \
# 27  28  first time   5054 2022-12-01   UNKNOWN   Mediashare  Free Talk
#
#     duration start_stream end_stream   days  hours  convert_duration_minutes
# 27  04:35:54     20:00:00      00:35  Kamis     20                     275.9

# %%
data[data["convert_duration_minutes"] == min(data["convert_duration_minutes"])]
# Out:
#     id                      title  views       date game_name  \
# 37  38  The Rise of Silvilization   3276 2022-12-18   UNKNOWN
#
#        content_name      topic  duration start_stream end_stream    days  \
# 37  Membership Open  Free Talk  01:04:46     19:00:00      20:04  Minggu
#
#     hours  convert_duration_minutes
# 37     19                     64.77

# %% [markdown]
# ### Check Correlation

# %%
plot_correlation(data=data)

# %% [markdown]
# - Berdasarkan hasil scatter plot dapat dilihat, ternyata korelasi tidak begitu kuat antara duration stream dengan views
# - Dapat dilihat antara stream selama 100 - 200 menit rata - rata views nya di 3k an

# %% [markdown]
# ### Silvia Livestream Topics

# %%
plot_livestream_topic(data=data, col_name="topic", username=USERNAME)

# %% [markdown]
# ### Storytelling Topic

# %%
free_talk = data[data["topic"] == "Free Talk"]

# %%
free_talk.head()
# Out:
#    id                                   title  views       date game_name  \
# 0   1  Ask me anything since I'm feeling nice   3039 2022-09-30   UNKNOWN
# 3   4                        gimana hari ini?   4578 2022-10-03   UNKNOWN
# 5   6                      pagi, latihan yuk?   3379 2022-10-08   UNKNOWN
# 6   7                     ga lucu = deportasi   3793 2022-10-08   UNKNOWN
# 8   9         menguji kekebalan melawan buaya   4509 2022-10-15   UNKNOWN
#
#                  content_name      topic  duration start_stream end_stream  \
# 0                     UNKNOWN  Free Talk  02:04:13     20:00:00      22:04
# 3                     UNKNOWN  Free Talk  01:41:08     19:30:00      21:11
# 5                    Guerilla  Free Talk  02:17:21     09:00:00      11:17
# 6  Waktu Silvia Menilai (WSM)  Free Talk  02:06:46     21:00:00      23:06
# 8  Waktu Silvia Menilai (WSM)  Free Talk  02:07:58     20:00:00      22:07
#
#      days  hours  convert_duration_minutes
# 0  Jum'at     20                    124.22
# 3   Senin     19                    101.13
# 5   Sabtu      9                    137.35
# 6   Sabtu     21                    126.77
# 8   Sabtu     20                    127.97

# %%
free_talk[free_talk["views"] == max(free_talk["views"])]
# Out:
#     id                               title  views       date game_name  \
# 31  32  membicarakan strategi untuk menang   5083 2022-12-08   UNKNOWN
#
#    content_name      topic  duration start_stream end_stream   days  hours  \
# 31   Mediashare  Free Talk  03:06:29     20:00:00      23:06  Kamis     20
#
#     convert_duration_minutes
# 31                    186.48

# %%
free_talk[free_talk["views"] == min(free_talk["views"])]
# Out:
#     id                title  views       date game_name content_name  \
# 18  19  day off, let's talk   1985 2022-11-13   UNKNOWN      UNKNOWN
#
#         topic  duration start_stream end_stream    days  hours  \
# 18  Free Talk  02:12:41     10:00:00      12:12  Minggu     10
#
#     convert_duration_minutes
# 18                    132.68

# %%
from matplotlib.dates import DateFormatter
plt.figure(figsize=(20,9))
ax = sns.lineplot(x = "date", y = "views", data=free_talk, marker='o', ci=None)
plt.ylim(0, 10000)
plt.title(f'{USERNAME} Free Talk Trend Views', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Views', fontsize=12)
# plt.show()
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)
plt.show()

# %%
wsm_data = data[data["content_name"] == "Waktu Silvia Menilai (WSM)"]

# %%
wsm_data
# Out:
#     id                                    title  views       date game_name  \
# 6    7                      ga lucu = deportasi   3793 2022-10-08   UNKNOWN
# 8    9          menguji kekebalan melawan buaya   4509 2022-10-15   UNKNOWN
# 20  21           apakah wallpaper kalian bagus?   3843 2022-11-18   UNKNOWN
# 21  22                 menilai wallpaper part 2   2467 2022-11-19   UNKNOWN
# 32  33  kita harus salut dengan dedikasi mereka   2752 2022-12-09   UNKNOWN
#
#                   content_name      topic  duration start_stream end_stream  \
# 6   Waktu Silvia Menilai (WSM)  Free Talk  02:06:46     21:00:00      23:06
# 8   Waktu Silvia Menilai (WSM)  Free Talk  02:07:58     20:00:00      22:07
# 20  Waktu Silvia Menilai (WSM)  Free Talk  01:39:42     20:00:00      21:39
# 21  Waktu Silvia Menilai (WSM)  Free Talk  01:19:54     15:00:00      16:19
# 32  Waktu Silvia Menilai (WSM)  Free Talk  01:10:32     15:15:00      16:25
#
#       days  hours  convert_duration_minutes
# 6    Sabtu     21                    126.77
# 8    Sabtu     20                    127.97
# 20  Jum'at     20                     99.70
# 21   Sabtu     15                     79.90
# 32  Jum'at     15                     70.53

# %%
from matplotlib.dates import DateFormatter
plt.figure(figsize=(20,9))
ax = sns.lineplot(x = "date", y = "views", data=wsm_data, marker='o', ci=None)
plt.ylim(0, 5000)
plt.title(f'{USERNAME} WSM Trend Views', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Views', fontsize=12)
# plt.show()
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)
plt.show()

# %% [markdown]
# ### Game Topic

# %%
data_game = data[data['topic'] == 'Game']

# %%
data_game.head()
# Out:
#    id                                    title  views       date  \
# 1   2  belajar menembak untuk memajukan negara   2548 2022-10-01
# 2   3                     tentara harus berani   1847 2022-10-02
# 4   5                           janji ga takut   1659 2022-10-07
# 7   8                          jadi ubi gepeng   2420 2022-10-12
# 9  10                          gampang ini mah   1404 2022-10-20
#
#            game_name content_name topic  duration start_stream end_stream  \
# 1           Valorant      UNKNOWN  Game  01:40:28     21:00:00      22:40
# 2   Dead by Daylight      UNKNOWN  Game  01:36:08     20:00:00      21:36
# 4             Ao Oni      UNKNOWN  Game  02:09:46     20:00:00      22:09
# 7             Ao Oni      UNKNOWN  Game  02:01:30     20:00:00      22:01
# 9  The Witch's House      UNKNOWN  Game  01:31:25     20:00:00      21:31
#
#      days  hours  convert_duration_minutes
# 1   Sabtu     21                    100.47
# 2  Minggu     20                     96.13
# 4  Jum'at     20                    129.77
# 7    Rabu     20                    121.50
# 9   Kamis     20                     91.42

# %% [markdown]
# ### Game List

# %%
plt.figure(figsize=(12,9))
plt.title(f'{USERNAME} Live Stream Topics')
ax = sns.countplot(y=data_game['game_name'], alpha=0.8, order = data_game['game_name'].value_counts().index)
ax.bar_label(ax.containers[0])
plt.show()

# %%
data_game[data_game["views"] == max(data_game["views"])]
# Out:
#     id                               title  views       date game_name  \
# 34  35  aku akan menjadi komandan terkeren   7874 2022-12-10     Nikke
#
#    content_name topic  duration start_stream end_stream   days  hours  \
# 34      UNKNOWN  Game  03:40:54     22:00:00      01:40  Sabtu     22
#
#     convert_duration_minutes
# 34                     220.9

# %%
data_game[data_game["views"] == min(data_game["views"])]
# Out:
#     id title  views       date game_name content_name topic  duration  \
# 17  18   dor   1350 2022-11-12  Valorant      UNKNOWN  Game  02:06:48
#
#    start_stream end_stream   days  hours  convert_duration_minutes
# 17     15:30:00      17:36  Sabtu     15                     126.8

# %% [markdown]
# ### Content Name

# %%
data_content = data[data["content_name"] != "UNKNOWN"]

# %%
data_content["content_name"].unique()
# Out:
# array(['Guerilla', 'Waktu Silvia Menilai (WSM)', 'Singing you to sleep',
#        'Mediashare', 'Unique games with Silvia (Usil)', 'Membership Open',
#        'Membership Reading'], dtype=object)

# %%
data_content.head()
# Out:
#     id                            title  views       date game_name  \
# 5    6               pagi, latihan yuk?   3379 2022-10-08   UNKNOWN
# 6    7              ga lucu = deportasi   3793 2022-10-08   UNKNOWN
# 8    9  menguji kekebalan melawan buaya   4509 2022-10-15   UNKNOWN
# 13  14                       kapan lagi   3260 2022-10-30   UNKNOWN
# 20  21   apakah wallpaper kalian bagus?   3843 2022-11-18   UNKNOWN
#
#                   content_name      topic  duration start_stream end_stream  \
# 5                     Guerilla  Free Talk  02:17:21     09:00:00      11:17
# 6   Waktu Silvia Menilai (WSM)  Free Talk  02:06:46     21:00:00      23:06
# 8   Waktu Silvia Menilai (WSM)  Free Talk  02:07:58     20:00:00      22:07
# 13        Singing you to sleep    Karaoke  01:32:16     21:30:00      23:02
# 20  Waktu Silvia Menilai (WSM)  Free Talk  01:39:42     20:00:00      21:39
#
#       days  hours  convert_duration_minutes
# 5    Sabtu      9                    137.35
# 6    Sabtu     21                    126.77
# 8    Sabtu     20                    127.97
# 13  Minggu     21                     92.27
# 20  Jum'at     20                     99.70

# %%
plt.figure(figsize=(12,9))
plt.title(f'{USERNAME} Content Name')
ax = sns.countplot(y=data_content['content_name'], alpha=0.8, order = data_content['content_name'].value_counts().index)
ax.bar_label(ax.containers[0])
plt.show()
